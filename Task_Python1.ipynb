# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat-kumar-sethi/Tasks/blob/main/Task_Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1. Student Name in Uppercase
student_name = input("Enter Student Name : ")
print(student_name.upper())
# Out:
# Enter Student Name : rajat
# RAJAT

# %%
#Q2. City Name Operations

city_name = input("Enter city name: ")

print("Original Name:", city_name)
print("Uppercase:", city_name.upper())
print("Lowercase:", city_name.lower())
print("Title Case:", city_name.title())
# Out:
# Enter city name: Rourkela
# Original Name: Rourkela
# Uppercase: ROURKELA
# Lowercase: rourkela
# Title Case: Rourkela

# %%
#Q3. Length of a String
text = input("Enter a string: ")

print("Total Length:", len(text))
# Out:
# Enter a string: i am invincible
# Total Length: 15

# %%
#Q4. First and Last Character
text = input("Enter a String:  ")
first_character = text[0]
last_character = text[-1]

print("First Character:", first_character)
print("Last Character:", last_character)
# Out:
# Enter a String:  ohio
# First Character: o
# Last Character: o

# %%
#Q5. Count Letter 'a'
text = input("Enter a string: ")

count_a = text.count('a')
print("Number of 'a' characters:", count_a)
# Out:
# Enter a string: Banana
# Number of 'a' characters: 3

# %%
#Q6. Replace Python with AI
sentence = input("Enter a sentence: ")

new_sentence = sentence.replace("Python", "AI")
print("Updated Sentence:", new_sentence)
# Out:
# Enter a sentence: Python is very easy
# Updated Sentence: AI is very easy

# %%
#Q7. Check Gmail Address
email_address = input("Enter email address: ")

if email_address.endswith("@gmail.com"):
    print("Valid Gmail Address")
else:
    print("Not a Gmail Address")
# Out:
# Enter email address: goba69@gmail.com
# Valid Gmail Address

# %%
#Q8. Check Only Digits
user_input = input("Enter something: ")

if user_input.isdigit():
    print("Contains only digits")
else:
    print("Does not contain only digits")
# Out:
# Enter something: nothing4a Pro
# Does not contain only digits

# %%
#Q9. Check Only Alphabets
user_input = input("Enter something: ")

if user_input.isalpha():
    print("Contains only alphabets")
else:
    print("Does not contain only alphabets")
# Out:
# Enter something: Nothing4a Pro
# Does not contain only alphabets

# %%
#Q10. Split String into List
fruit_string = "Apple,Mango,Banana,Orange"

fruit_list = fruit_string.split(",")
print("List:", fruit_list)
# Out:
# List: ['Apple', 'Mango', 'Banana', 'Orange']

# %%
#Q12. Positive, Negative or Zero
number = float(input("Enter a number: "))

if number > 0:
    print("Positive Number")
elif number < 0:
    print("Negative Number")
else:
    print("Zero")
# Out:
# Enter a number: 67
# Positive Number

# %%
#Q13. Greater Number Between Two Numbers
first_number = float(input("Enter first number: "))
second_number = float(input("Enter second number: "))

if first_number > second_number:
    print("Greater Number:", first_number)
else:
    print("Greater Number:", second_number)
# Out:
# Enter first number: 7576
# Enter second number: 5465
# Greater Number: 7576.0

# %%
#Q14. Grade Assignment
marks = int(input("Enter marks: "))

if 90 <= marks <= 100:
    print("Grade A")
elif 75 <= marks <= 89:
    print("Grade B")
elif 50 <= marks <= 74:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks: 65
# Grade C

# %%
#Q15. Even or Odd
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number: 7
# Odd Number

# %%
#Q16. Strong or Weak Password
password = input("Enter password: ")

if len(password) >= 8:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter password: ChikenCurryA1@
# Strong Password

# %%
#Q17. Leap Year Check
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year: 2020
# Leap Year

# %%
#Q18. Largest Among Three Numbers
first_number = float(input("Enter first number: "))
second_number = float(input("Enter second number: "))
third_number = float(input("Enter third number: "))

if first_number >= second_number and first_number >= third_number:
    print("Largest Number:", first_number)
elif second_number >= first_number and second_number >= third_number:
    print("Largest Number:", second_number)
else:
    print("Largest Number:", third_number)
# Out:
# Enter first number: 21
# Enter second number: 42
# Enter third number: 41
# Largest Number: 42.0

# %%
#Q19. Login Validation
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful

# %%
#Q20. Simple Calculator
first_number = float(input("Enter first number: "))
second_number = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result:", first_number + second_number)
elif operator == "-":
    print("Result:", first_number - second_number)
elif operator == "*":
    print("Result:", first_number * second_number)
elif operator == "/":
    if second_number != 0:
        print("Result:", first_number / second_number)
    else:
        print("Division by zero is not allowed")
else:
    print("Invalid Operator")
# Out:
# Enter first number: 10
# Enter second number: 3
# Enter operator (+, -, *, /): /
# Result: 3.3333333333333335
