# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat-kumar-sethi/Tasks/blob/main/Task_python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#q1

students =['Rajat','Rizzler','mogger','Swagger']
print('Students Names :')

for student in students:
  print(student)
# Out:
# Students Names :
# Rajat
# Rizzler
# mogger
# Swagger

# %%
#q2

numbers = [67, 20, 35, 40, 10]

print("First Element:", numbers[0])
print("Last Element:", numbers[-1])
# Out:
# First Element: 67
# Last Element: 10

# %%
#q3

fruits = ["Apple", "Banana", "Mango"]

fruits.append("kiwi")

print("Updated Fruit List:", fruits)
# Out:
# Updated Fruit List: ['Apple', 'Banana', 'Mango', 'kiwi']

# %%
#q4

subjects = ["Python", "Java", "C", "C++"]

subjects.insert(2,"AI")

print("Updated Subjects:", subjects)
# Out:
# Updated Subjects: ['Python', 'Java', 'AI', 'C', 'C++']

# %%
#q5

numbers = [10, 20, 30, 40, 50]

numbers.pop(2)

print("Updated List:", numbers)
# Out:
# Updated List: [10, 20, 40, 50]

# %%
#q6
numbers = [10, 20, 30, 40, 50]

print("Length:", len(numbers))
print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
print("Sum:", sum(numbers))
# Out:
# Length: 5
# Maximum: 50
# Minimum: 10
# Sum: 150

# %%
#q7

numbers =[]

for  i in range (5):
  num = (int(input(f"Enter number {i+1}:")))
  numbers.append(num)
print("Complete List :",numbers)
# Out:
# Enter number 1:11
# Enter number 2:22
# Enter number 3:33
# Enter number 4:44
# Enter number 5:55
# Complete List : [11, 22, 33, 44, 55]

# %%
#q8

cities = ["Bhubaneswar", "Delhi", "Chennai", "Kolkata"]

if "Delhi" in cities:
    print("Delhi exists in the list.")
else:
    print("Delhi does not exist in the list.")
# Out:
# Delhi exists in the list.

# %%
#q9

colors = ("Red", "Blue", "Green", "Pink", "Black")

print("Colors:")
for color in colors:
    print(color)
# Out:
# Colors:
# Red
# Blue
# Green
# Pink
# Black

# %%
#q10

numbers = (10, 20, 30, 40, 50)

print("First Element:", numbers[0])
print("Last Element:", numbers[-1])
# Out:
# First Element: 10
# Last Element: 50

# %%
#q11

students = ("Rajat", "Amit", "likun", "Rajat", "Rajat")

name = "Rajat"

print(f"{name} appeared", students.count(name), "times")
# Out:
# Rajat appeared 3 times

# %%
#12

numbers = (12, 24, 36, 48, 60)

print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
print("Length:", len(numbers))
# Out:
# Maximum: 60
# Minimum: 12
# Length: 5

# %%
#q13

numbers = (10, 20, 30)

numbers[2] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2005/2268703972.py in <cell line: 0>()
#       3 numbers = (10, 20, 30)
#       4
# ----> 5 numbers[2] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#q14

data = (11, 22, 33, 44, 55)

new_list = list(data)

print("Converted List:", new_list)
# Out:
# Converted List: [11, 22, 33, 44, 55]

# %%
#q15

numbers = {10, 20, 30, 40, 50}

print(numbers)
# Out:
# {50, 20, 40, 10, 30}

# %%
#q16

numbers = {10, 20, 30}

numbers.add(40)

print("Updated Set:", numbers)
# Out:
# Updated Set: {40, 10, 20, 30}

# %%
#q17

numbers = {10, 20, 30, 40}

numbers.remove(20)

print("Updated Set:", numbers)
# Out:
# Updated Set: {40, 10, 30}

# %%
#q18

numbers = {10, 20, 20, 30, 30, 40}

print(numbers)
# Out:
# {40, 10, 20, 30}

# %%
#q19

A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A | B)
print("Intersection:", A & B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}

# %%
numbers = {10, 20, 30, 40, 50}

num = int(input("Enter a number: "))

if num in numbers:
    print("Number found")
else:
    print("Number not found")
# Out:
# Enter a number: 20
# Number found

# %%
#q21

person = {
    "name": "Sia",
    "age": 15 ,
    "city": "Bhubaneswar"
}

print(person.values())
# Out:
# dict_values(['R', 15, 'Bhubaneswar'])

# %%
#q22

student = {
    "name": "Siva",
    "age": 24
}

student["course"] = "Python"

print(student)
# Out:
# {'name': 'Siva', 'age': 24, 'course': 'Python'}

# %%
#23

employee = {
    "id": 10786,
    "name": "Peter Parker",
    "salary": 50000
}

print("Keys:", employee.keys())
print("Values:", employee.values())
# Out:
# Keys: dict_keys(['id', 'name', 'salary'])
# Values: dict_values([10786, 'Peter Parker', 50000])

# %%
#24

student = {
    "name": "Peter Parker",
    "age": 29
}

student["age"] = 25

print(student)
# Out:
# {'name': 'Peter Parker', 'age': 25}

# %%
#25

person = {
    "name": "Test",
    "age": 24,
    "city": "Chennai"
}

person.pop("city")

print(person)
# Out:
# {'name': 'Test', 'age': 24}

# %%
#26

marks = {
    "Rajat": 85,
    "Ana": 92,
    "Ria": 78,
    "Sia": 88,
    "Mia": 75
}

print("Student Names:")

for name in marks.keys():
    print(name)
# Out:
# Student Names:
# Rajat
# Ana
# Ria
# Sia
# Mia

# %%
#27

products = {
    "laptop": 55000,
    "mobile": 25000,
    "tablet": 2000
}

product = input("Enter product name: ")

print("Price:", products[product])
# Out:
# Enter product name: tablet
# Price: 2000

# %%
#28

student = {
    "name": "Rajat",
    "age": 99,
    "course": "Python"
}

key = input("Enter key: ")

if key in student:
    print("Key exists.")
else:
    print("Key does not exist.")
# Out:
# Enter key: age
# Key exists.

# %%
#29

students = ["Rajat", "Ria", "Sia", "Jia", "Kia"]

student_tuple = tuple(students)

print(student_tuple)
# Out:
# ('Rajat', 'Ria', 'Sia', 'Jia', 'Kia')

# %%
#30

marks = {
    "Flash": 85,
    "Komal": 92,
    "Lochon": 76,
    "Andana": 88,
    "peter": 65
}

for student in marks:
    if marks[student] > 80:
        print(student)
# Out:
# Flash
# Komal
# Andana
